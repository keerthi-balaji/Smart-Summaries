# %%
# upgrade datasets optional

# !pip install -U datasets
# Out:
# Requirement already satisfied: datasets in c:\users\keert\appdata\roaming\python\python311\site-packages (2.20.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
#install libraries for loading and finetuning gpt2 
# !pip install transformers datasets torch
# Out:
# Requirement already satisfied: transformers in c:\programdata\anaconda3\lib\site-packages (4.37.2)
# Requirement already satisfied: datasets in c:\users\keert\appdata\roaming\python\python311\site-packages (2.20.0)
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\programdata\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in c:\users\keert\appdata\roaming\python\python311\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\programdata\anaconda3\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\keert\appdata\roaming\python\python311\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\keert\appdata\roaming\python\python311\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in c:\programdata\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\programdata\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\programdata\anaconda3\lib\site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# import library to load the dataset
from datasets import load_dataset, Dataset

# %%
#load dataset
dataset = load_dataset("ccdv/pubmed-summarization")

# %%
#creating dataframe
import pandas as pd

df = pd.DataFrame(dataset['train'])

# %%
#printing first few rows of dataset

df.head()
# Out:
#                                              article  \
# 0  a recent systematic analysis showed that in 20...
# 1  it occurs in more than 50% of patients and may...
# 2  tardive dystonia ( td ) , a rarer side effect ...
# 3  lepidoptera include agricultural pests that , ...
# 4  syncope is caused by transient diffuse cerebra...
#
#                                             abstract
# 0  background : the present study was carried out...
# 1  backgroundanemia in patients with cancer who a...
# 2  tardive dystonia ( td ) is a serious side effe...
# 3  many lepidopteran insects are agricultural pes...
# 4  we present an unusual case of recurrent cough ...

# %%
# Calculate the number of characters in 'article' and 'abstract' columns
df['article_char_count'] = df['article'].apply(len)
df['abstract_char_count'] = df['abstract'].apply(len)

# %%
#printing first few rows of dataset

df.head()
# Out:
#                                              article  \
# 0  a recent systematic analysis showed that in 20...
# 1  it occurs in more than 50% of patients and may...
# 2  tardive dystonia ( td ) , a rarer side effect ...
# 3  lepidoptera include agricultural pests that , ...
# 4  syncope is caused by transient diffuse cerebra...
#
#                                             abstract  article_char_count  \
# 0  background : the present study was carried out...               28460
# 1  backgroundanemia in patients with cancer who a...               18281
# 2  tardive dystonia ( td ) is a serious side effe...                7419
# 3  many lepidopteran insects are agricultural pes...               37370
# 4  we present an unusual case of recurrent cough ...                6918
#
#    abstract_char_count
# 0                 1575
# 1                 2010
# 2                 1009
# 3                 1403
# 4                 1039

# %%
# statistics of the count columns

df[['article_char_count','abstract_char_count']].describe()
# Out:
#        article_char_count  abstract_char_count
# count       119924.000000        119924.000000
# mean         17585.276233          1233.188486
# std          14599.306969           461.285535
# min              0.000000           174.000000
# 25%           8560.000000           886.000000
# 50%          14879.000000          1276.000000
# 75%          22979.250000          1582.000000
# max         825741.000000          4340.000000

# %%
# printing the rows with no value in article columns

df.loc[df['article_char_count'] == 0]
# Out:
#        article                                           abstract  \
# 11              we compared serum polychlorinated dibenzo - p ...
# 22              because of rampant concern that estrogenic che...
# 50              we have prepared two new diastereoisomeric \n ...
# 151             mypro is a software pipeline for high - qualit...
# 175             octane - enhancing constituents of gasoline po...
# ...        ...                                                ...
# 119745          cells comprising a tissue migrate as part of a...
# 119841          pathologic response of tissue to asbestos in v...
# 119847          adequate cognitive functioning is essential fo...
# 119863          the aluminum concentration and ryznar index in...
# 119886          the goal of the present study was to determine...
#
#         article_char_count  abstract_char_count
# 11                       0                 2008
# 22                       0                 1839
# 50                       0                  625
# 151                      0                  373
# 175                      0                 1071
# ...                    ...                  ...
# 119745                   0                 1221
# 119841                   0                 1490
# 119847                   0                  453
# 119863                   0                 1384
# 119886                   0                 2028
#
# [2692 rows x 4 columns]

# %%
#removing the rows with no value in article columns

df= df[df['article_char_count'] != 0]

# %%
# confirmed that the rows with no value in article columns

df.loc[df['article_char_count'] == 0]
# Out:
# Empty DataFrame
# Columns: [article, abstract, article_char_count, abstract_char_count]
# Index: []

# %%
# printing stats for the counts

df[['article_char_count','abstract_char_count']].describe()
# Out:
#        article_char_count  abstract_char_count
# count       117232.000000        117232.000000
# mean         17989.087169          1235.163505
# std          14517.915998           460.254653
# min              3.000000           205.000000
# 25%           8927.750000           890.000000
# 50%          15163.500000          1280.000000
# 75%          23228.000000          1582.000000
# max         825741.000000          4340.000000

# %%
# plotting the counts in box plots

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.boxplot(df['article_char_count'], vert=False)
plt.title('Box plot of article_char_count')
plt.xlabel('Number of Characters')
plt.show()

plt.figure(figsize=(10, 5))
plt.boxplot(df['abstract_char_count'], vert=False)
plt.title('Box plot of abstract_char_count')
plt.xlabel('Number of Characters')
plt.show()

# %%
# printing rows with articles of character length less than 1000

df.loc[df['article_char_count'] < 1000]
# Out:
#                                                   article  \
# 94       \n supported by nci 2p50 ca09825806 , nci u01...
# 155      \n  \n we are grateful for financial support ...
# 390     bspp : bisulfite padlock probe ; charm : compr...
# 399     as a service to our authors and readers , this...
# 456     to identify the possible barriers to the imple...
# ...                                                   ...
# 119619  the online version of this article ( doi:10.10...
# 119750  the presented data from literature and own det...
# 119821                                                \n
# 119875  while trying to integrate multiple data sets c...
# 119906  the author receives funding from the swedish r...
#
#                                                  abstract  article_char_count  \
# 94      pik3r1 ( encoding the p85 subunit of phosphati...                 278
# 155     abstractbacterial volatiles protect plants eit...                 281
# 390     dna methylation of promoter cpg islands is str...                 714
# 399     abstractmacrocyclization can be used to constr...                 357
# 456     objective : to identify the possible barriers ...                 898
# ...                                                   ...                 ...
# 119619  high fruit and wine quality combined with good...                 269
# 119750  so far , a fatty pancreas has been related to ...                 784
# 119821  summarypoly(adp - ribose ) polymerases ( parps...                   3
# 119875  background : while trying to integrate multipl...                 840
# 119906  common genetic variations in the gene encoding...                 817
#
#         abstract_char_count
# 94                      387
# 155                     866
# 390                    1223
# 399                     991
# 456                    1022
# ...                     ...
# 119619                 1476
# 119750                 2182
# 119821                 1341
# 119875                 1002
# 119906                  377
#
# [1085 rows x 4 columns]

# %%
# printing rows with articles of character length less than that of the abstracts

df.loc[df['article_char_count'] < df['abstract_char_count']]
# Out:
#                                                   article  \
# 71      care coordination is an important aspect of nu...
# 94       \n supported by nci 2p50 ca09825806 , nci u01...
# 128     established in 2003 , erste foundation has a h...
# 155      \n  \n we are grateful for financial support ...
# 291     ala - al - din abu al - hassan ali ibn abi - h...
# ...                                                   ...
# 119619  the online version of this article ( doi:10.10...
# 119684  to assess attitudes and practices of documenta...
# 119750  the presented data from literature and own det...
# 119821                                                \n
# 119875  while trying to integrate multiple data sets c...
#
#                                                  abstract  article_char_count  \
# 71      introductioncare coordination is an important ...                2126
# 94      pik3r1 ( encoding the p85 subunit of phosphati...                 278
# 128     introductionestablished in 2003 , erste founda...                1399
# 155     abstractbacterial volatiles protect plants eit...                 281
# 291     background : ala - al - din abu al - hassan al...                1457
# ...                                                   ...                 ...
# 119619  high fruit and wine quality combined with good...                 269
# 119684  purposes : to assess attitudes and practices o...                1013
# 119750  so far , a fatty pancreas has been related to ...                 784
# 119821  summarypoly(adp - ribose ) polymerases ( parps...                   3
# 119875  background : while trying to integrate multipl...                 840
#
#         abstract_char_count
# 71                     2309
# 94                      387
# 128                    1462
# 155                     866
# 291                    1709
# ...                     ...
# 119619                 1476
# 119684                 1140
# 119750                 2182
# 119821                 1341
# 119875                 1002
#
# [1455 rows x 4 columns]

# %%
# printing rows with articles of character length equal to that of the abstracts

df.loc[df['article_char_count'] == df['abstract_char_count']]
# Out:
#                                                 article  \
# 7676  the maldi - tof ms spectrum of  c.  massiliens...
#
#                                                abstract  article_char_count  \
# 7676  we report the main characteristics of a new ge...                 293
#
#       abstract_char_count
# 7676                  293

# %%
# removing rows with articles of character length less than or equal to that of the abstracts

df_cleaned = df.loc[df['article_char_count'] >= df['abstract_char_count']]

# %%
# printing the statistics

df_cleaned[['article_char_count','abstract_char_count']].describe()
# Out:
#        article_char_count  abstract_char_count
# count       115777.000000        115777.000000
# mean         18206.835520          1236.069833
# std          14477.362483           459.327471
# min            281.000000           205.000000
# 25%           9136.000000           893.000000
# 50%          15322.000000          1281.000000
# 75%          23363.000000          1582.000000
# max         825741.000000          4340.000000

# %%
# printing first few rows of the preprocessed dataset

df_cleaned.head()
# Out:
#                                              article  \
# 0  a recent systematic analysis showed that in 20...
# 1  it occurs in more than 50% of patients and may...
# 2  tardive dystonia ( td ) , a rarer side effect ...
# 3  lepidoptera include agricultural pests that , ...
# 4  syncope is caused by transient diffuse cerebra...
#
#                                             abstract  article_char_count  \
# 0  background : the present study was carried out...               28460
# 1  backgroundanemia in patients with cancer who a...               18281
# 2  tardive dystonia ( td ) is a serious side effe...                7419
# 3  many lepidopteran insects are agricultural pes...               37370
# 4  we present an unusual case of recurrent cough ...                6918
#
#    abstract_char_count
# 0                 1575
# 1                 2010
# 2                 1009
# 3                 1403
# 4                 1039

# %%
# plotting the counts in box plots

plt.figure(figsize=(10, 5))
plt.boxplot(df_cleaned['article_char_count'], vert=False)
plt.title('Box plot of article_char_count')
plt.xlabel('Number of Characters')
plt.show()

plt.figure(figsize=(10, 5))
plt.boxplot(df_cleaned['abstract_char_count'], vert=False)
plt.title('Box plot of abstract_char_count')
plt.xlabel('Number of Characters')
plt.show()

# %%
#looking at the outliers in the abstract column

df_cleaned.loc[df_cleaned['abstract_char_count'] >2615]
# Out:
#                                                  article  \
# 3665   the normal prostate luminal cells , which are ...
# 29647  atrial fibrillation ( af ) continues to affect...
# 32390  deep brain stimulation ( dbs ) is an effective...
# 43030  the four color theorem [ 1 , 2 ] asserts that ...
# 49109  dehydration and overhydration entail a deficie...
# 67896  measurements of the heavy quarkonium productio...
#
#                                                 abstract  article_char_count  \
# 3665   our recent studies revealed that focal basal c...               20291
# 29647  changes in cardiac tissue properties following...               20677
# 32390  design of a rectangular spiral planar inverted...               72951
# 43030  this paper extends the scenario of the four co...              271161
# 49109  the level of hydration in the human body is ca...               67908
# 67896  the polarisation of prompt \documentclass[12pt...              332580
#
#        abstract_char_count
# 3665                  2720
# 29647                 2967
# 32390                 2663
# 43030                 4340
# 49109                 2763
# 67896                 2817

# %%
# dropping columns article_char_count and abstract_char_count

df_cleaned = df_cleaned.drop(['article_char_count', 'abstract_char_count'], axis=1)

# %%
# printing first few rows of the processed dataset
df_cleaned.head()
# Out:
#                                              article  \
# 0  a recent systematic analysis showed that in 20...
# 1  it occurs in more than 50% of patients and may...
# 2  tardive dystonia ( td ) , a rarer side effect ...
# 3  lepidoptera include agricultural pests that , ...
# 4  syncope is caused by transient diffuse cerebra...
#
#                                             abstract
# 0  background : the present study was carried out...
# 1  backgroundanemia in patients with cancer who a...
# 2  tardive dystonia ( td ) is a serious side effe...
# 3  many lepidopteran insects are agricultural pes...
# 4  we present an unusual case of recurrent cough ...

# %%
# Saved the cleaned dataframe to a CSV file
df_cleaned.to_csv('cleaned_train.csv', index=False)

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments

# Loading the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %%
# Converted the DataFrame to a Dataset
processed_dataset = Dataset.from_pandas(df_cleaned)

# %%
# tokenize function
def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True, padding='max_length', max_length=512)

# Applying the tokenize function to the dataset
tokenized_dataset = processed_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/115777 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 6
#       3     return tokenizer(examples["text"], truncation=True, padding='max_length', max_length=512)
#       5 # Applying the tokenize function to the dataset
# ----> 6 tokenized_dataset = processed_dataset.map(tokenize_function, batched=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:3161, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3155 if transformed_dataset is None:
#    3156     with hf_tqdm(
#    3157         unit=" examples",
#    3158         total=pbar_total,
#    3159         desc=desc or "Map",
#    3160     ) as pbar:
# -> 3161         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3162             if done:
#    3163                 shards_done += 1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:3552, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3548 indices = list(
#    3549     range(*(slice(i, i + batch_size).indices(shard.num_rows)))
#    3550 )  # Something simpler?
#    3551 try:
# -> 3552     batch = apply_function_on_filtered_inputs(
#    3553         batch,
#    3554         indices,
#    3555         check_same_num_examples=len(shard.list_indexes()) > 0,
#    3556         offset=offset,
#    3557     )
#    3558 except NumExamplesMismatchError:
#    3559     raise DatasetTransformationNotAllowedError(
#    3560         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3561     ) from None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\arrow_dataset.py:3421, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3419 if with_rank:
#    3420     additional_args += (rank,)
# -> 3421 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3422 if isinstance(processed_inputs, LazyDict):
#    3423     processed_inputs = {
#    3424         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3425     }
#
# Cell In[31], line 3, in tokenize_function(examples)
#       2 def tokenize_function(examples):
# ----> 3     return tokenizer(examples["text"], truncation=True, padding='max_length', max_length=512)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\formatting\formatting.py:271, in LazyDict.__getitem__(self, key)
#     270 def __getitem__(self, key):
# --> 271     value = self.data[key]
#     272     if key in self.keys_to_format:
#     273         value = self.format(key)
#
# KeyError: 'text'
